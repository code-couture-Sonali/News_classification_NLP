# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
# Out:
# WARNING:tensorflow:From E:\anaconda3\envs\senti\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Load the CSV file
df = pd.read_csv(r'C:\Users\The Emoji Girl\OneDrive\Documents\Datasets\agnews_test.csv', names=['Class', 'Title', 'Description'])
df
# Out:
#             Class                                              Title  \
# 0     Class Index                                              Title
# 1               3                  Fears for T N pension after talks
# 2               4  The Race is On: Second Private Team Sets Launc...
# 3               4      Ky. Company Wins Grant to Study Peptides (AP)
# 4               4      Prediction Unit Helps Forecast Wildfires (AP)
# ...           ...                                                ...
# 7596            1                                   Around the world
# 7597            2                        Void is filled with Clement
# 7598            2                             Martinez leaves bitter
# 7599            3  5 of arthritis patients in Singapore take Bext...
# 7600            3                             EBay gets into rentals
#
#                                             Description
# 0                                           Description
# 1     Unions representing workers at Turner   Newall...
# 2     SPACE.com - TORONTO, Canada -- A second\team o...
# 3     AP - A company founded by a chemistry research...
# 4     AP - It's barely dawn when Mike Fitzpatrick st...
# ...                                                 ...
# 7596  Ukrainian presidential candidate Viktor Yushch...
# 7597  With the supply of attractive pitching options...
# 7598  Like Roger Clemens did almost exactly eight ye...
# 7599  SINGAPORE : Doctors in the United States have ...
# 7600  EBay plans to buy the apartment and home renta...
#
# [7601 rows x 3 columns]

# %%
# Remove header row
df = df[df['Class'] != 'Class Index'].copy()

# Convert class to integer and combine title and description
df['Class'] = df['Class'].astype(int)
df['Text'] = df['Title'] + ' ' + df['Description']
df
# Out:
#       Class                                              Title  \
# 1         3                  Fears for T N pension after talks
# 2         4  The Race is On: Second Private Team Sets Launc...
# 3         4      Ky. Company Wins Grant to Study Peptides (AP)
# 4         4      Prediction Unit Helps Forecast Wildfires (AP)
# 5         4        Calif. Aims to Limit Farm-Related Smog (AP)
# ...     ...                                                ...
# 7596      1                                   Around the world
# 7597      2                        Void is filled with Clement
# 7598      2                             Martinez leaves bitter
# 7599      3  5 of arthritis patients in Singapore take Bext...
# 7600      3                             EBay gets into rentals
#
#                                             Description  \
# 1     Unions representing workers at Turner   Newall...
# 2     SPACE.com - TORONTO, Canada -- A second\team o...
# 3     AP - A company founded by a chemistry research...
# 4     AP - It's barely dawn when Mike Fitzpatrick st...
# 5     AP - Southern California's smog-fighting agenc...
# ...                                                 ...
# 7596  Ukrainian presidential candidate Viktor Yushch...
# 7597  With the supply of attractive pitching options...
# 7598  Like Roger Clemens did almost exactly eight ye...
# 7599  SINGAPORE : Doctors in the United States have ...
# 7600  EBay plans to buy the apartment and home renta...
#
#                                                    Text
# 1     Fears for T N pension after talks Unions repre...
# 2     The Race is On: Second Private Team Sets Launc...
# 3     Ky. Company Wins Grant to Study Peptides (AP) ...
# 4     Prediction Unit Helps Forecast Wildfires (AP) ...
# 5     Calif. Aims to Limit Farm-Related Smog (AP) AP...
# ...                                                 ...
# 7596  Around the world Ukrainian presidential candid...
# 7597  Void is filled with Clement With the supply of...
# 7598  Martinez leaves bitter Like Roger Clemens did ...
# 7599  5 of arthritis patients in Singapore take Bext...
# 7600  EBay gets into rentals EBay plans to buy the a...
#
# [7600 rows x 4 columns]

# %%
max_features = 10000  # vocabulary size

# Prepare the data
texts = df['Text'].tolist()
labels = (df['Class'] - 1).values  # Convert 1-4 to 0-3

# Split the data
from sklearn.model_selection import train_test_split
X_train_text, X_test_text, y_train, y_test = train_test_split(
    texts, labels, test_size=0.2, random_state=42, stratify=labels
)

# Print the shape of the data
print(f'Training data shape: {len(X_train_text)}, Training labels shape: {len(y_train)}')
print(f'Testing data shape: {len(X_test_text)}, Testing labels shape: {len(y_test)}')
# Out:
# Training data shape: 6080, Training labels shape: 6080
# Testing data shape: 1520, Testing labels shape: 1520

# %%
# Tokenize the text data
tokenizer = Tokenizer(num_words=max_features, oov_token="<OOV>")
tokenizer.fit_on_texts(X_train_text)

# Convert texts to sequences
X_train = tokenizer.texts_to_sequences(X_train_text)
X_test = tokenizer.texts_to_sequences(X_test_text)

X_train[0]
# Out:
# [122, 479, 217, 1, 594, 1193, 1, 2984, 78, 122, 8, 69, 4355, 60, 1736]

# %%
# Mapping of words index back to words (for understanding)
word_index = tokenizer.word_index
reverse_word_index = {value: key for key, value in word_index.items()}
reverse_word_index
# Out:
# {1: '<OOV>',
#  2: 'the',
#  3: 'to',
#  4: 'a',
#  5: 'of',
#  6: 'in',
#  7: 'and',
#  8: 'on',
#  9: 'for',
#  10: '39',
#  11: 's',
#  12: 'that',
#  13: 'with',
#  14: 'at',
#  15: 'as',
#  16: 'its',
#  17: 'is',
#  18: 'new',
#  19: 'by',
#  20: 'said',
#  21: 'it',
#  22: 'has',
#  23: 'reuters',
#  24: 'from',
#  25: 'ap',
#  26: 'an',
#  27: 'after',
#  28: 'his',
#  29: 'will',
#  30: 'was',
#  31: 'us',
#  32: 'gt',
#  33: 'lt',
#  34: 'have',
#  35: 'over',
#  36: 'two',
#  37: 'first',
#  38: 'be',
#  39: 'up',
#  40: 'their',
#  41: 'year',
#  42: 'quot',
#  43: 'are',
#  44: 'this',
#  45: 'he',
#  46: 'more',
#  47: 'but',
#  48: 'one',
#  49: 'monday',
#  50: 'u',
#  51: 'out',
#  52: 'tuesday',
#  53: '1',
#  54: 'thursday',
#  55: 'against',
#  56: 'wednesday',
#  57: 'world',
#  58: 'oil',
#  59: 'company',
#  60: 'into',
#  61: 'inc',
#  62: '2',
#  63: 'microsoft',
#  64: 'than',
#  65: 'not',
#  66: 'who',
#  67: 'last',
#  68: 'they',
#  69: 'friday',
#  70: 'been',
#  71: 'york',
#  72: 'were',
#  73: 'b',
#  74: 'million',
#  75: 'about',
#  76: 'iraq',
#  77: 'three',
#  78: 'president',
#  79: 'week',
#  80: 'time',
#  81: 'united',
#  82: 'game',
#  83: 'no',
#  84: 'second',
#  85: 'could',
#  86: 'yesterday',
#  87: 'com',
#  88: 'afp',
#  89: 'when',
#  90: 'next',
#  91: 'years',
#  92: 'says',
#  93: 'would',
#  94: 'may',
#  95: 'off',
#  96: 'had',
#  97: '3',
#  98: 'sunday',
#  99: 'group',
#  100: 'prices',
#  101: 'security',
#  102: 'percent',
#  103: 'corp',
#  104: 'people',
#  105: 'government',
#  106: 'stocks',
#  107: 'back',
#  108: 'today',
#  109: 'n',
#  110: 'which',
#  111: 'software',
#  112: 'all',
#  113: 'day',
#  114: 'season',
#  115: 'win',
#  116: 'team',
#  117: 'some',
#  118: 'high',
#  119: 'quarter',
#  120: '4',
#  121: 'state',
#  122: 'bush',
#  123: '6',
#  124: 'china',
#  125: 'internet',
#  126: 'end',
#  127: 'open',
#  128: 'court',
#  129: 'or',
#  130: 'plans',
#  131: 'market',
#  132: 'deal',
#  133: 'top',
#  134: 'announced',
#  135: 'report',
#  136: '10',
#  137: 'down',
#  138: 'record',
#  139: 'news',
#  140: '2004',
#  141: 'billion',
#  142: 't',
#  143: 'third',
#  144: 'saturday',
#  145: 'service',
#  146: '5',
#  147: 'business',
#  148: 'four',
#  149: 'fullquote',
#  150: 'profit',
#  151: 'washington',
#  152: 'city',
#  153: 'most',
#  154: 'night',
#  155: 'european',
#  156: 'sales',
#  157: 'killed',
#  158: 'other',
#  159: 'just',
#  160: 'officials',
#  161: 'can',
#  162: 'talks',
#  163: 'international',
#  164: 'minister',
#  165: 'states',
#  166: 'set',
#  167: 'if',
#  168: 'league',
#  169: 'lead',
#  170: '0',
#  171: 'technology',
#  172: 'co',
#  173: 'former',
#  174: 'before',
#  175: 'month',
#  176: 'take',
#  177: 'home',
#  178: 'largest',
#  179: 'make',
#  180: 'victory',
#  181: 'bid',
#  182: 'computer',
#  183: 'shares',
#  184: 'there',
#  185: 'expected',
#  186: 'american',
#  187: 'search',
#  188: 'between',
#  189: 'chief',
#  190: 'final',
#  191: 'you',
#  192: 'now',
#  193: '000',
#  194: 'federal',
#  195: '7',
#  196: 'another',
#  197: 'british',
#  198: 'won',
#  199: 'red',
#  200: 'major',
#  201: 'least',
#  202: 'during',
#  203: 'space',
#  204: 'google',
#  205: 'cup',
#  206: 'national',
#  207: 'help',
#  208: 'say',
#  209: 'police',
#  210: 'companies',
#  211: 'al',
#  212: 'hit',
#  213: 'what',
#  214: 'war',
#  215: 'run',
#  216: 'india',
#  217: 'trade',
#  218: 'five',
#  219: 'japan',
#  220: 'network',
#  221: 'buy',
#  222: 'data',
#  223: 'mobile',
#  224: 'still',
#  225: 'bank',
#  226: 'industry',
#  227: 'reported',
#  228: 'target',
#  229: 'big',
#  230: 'long',
#  231: 'giant',
#  232: 'according',
#  233: 'maker',
#  234: 'south',
#  235: 'nuclear',
#  236: 'online',
#  237: 'games',
#  238: 'election',
#  239: 'services',
#  240: 'move',
#  241: 'baghdad',
#  242: 'higher',
#  243: 'days',
#  244: 'linux',
#  245: 'plan',
#  246: 'un',
#  247: 'i',
#  248: 'san',
#  249: 'ibm',
#  250: 'research',
#  251: 'made',
#  252: 'while',
#  253: 'get',
#  254: 'them',
#  255: 'wireless',
#  256: 'cut',
#  257: 'gold',
#  258: 'prime',
#  259: 'start',
#  260: 'london',
#  261: 'based',
#  262: 'gaza',
#  263: 'series',
#  264: 'since',
#  265: 'six',
#  266: 'web',
#  267: 'early',
#  268: 'general',
#  269: 'under',
#  270: 'country',
#  271: 'left',
#  272: 'ticker',
#  273: 'iraqi',
#  274: 'old',
#  275: 'way',
#  276: 'ahead',
#  277: 'through',
#  278: 'intel',
#  279: 'music',
#  280: 'australia',
#  281: 'earnings',
#  282: 'loss',
#  283: 'system',
#  284: 'http',
#  285: 'test',
#  286: 'growth',
#  287: 'israeli',
#  288: 'athens',
#  289: 'dollar',
#  290: 'air',
#  291: 'p',
#  292: 'union',
#  293: 'coach',
#  294: 'olympic',
#  295: 'sports',
#  296: 'north',
#  297: 'free',
#  298: 'england',
#  299: 'go',
#  300: 'held',
#  301: 'pay',
#  302: 'href',
#  303: 'www',
#  304: 'boston',
#  305: 'like',
#  306: 'sox',
#  307: 'many',
#  308: 'update',
#  309: 'so',
#  310: 'half',
#  311: 'phone',
#  312: 'football',
#  313: 'attack',
#  314: 'players',
#  315: 'investor',
#  316: 'military',
#  317: 'o',
#  318: 'eu',
#  319: 'troops',
#  320: 'months',
#  321: 'how',
#  322: 'investors',
#  323: 'windows',
#  324: 'global',
#  325: 'case',
#  326: 'round',
#  327: 'including',
#  328: 'even',
#  329: 'biggest',
#  330: 'key',
#  331: '2005',
#  332: 'economic',
#  333: 'john',
#  334: 'leader',
#  335: 'only',
#  336: 'russian',
#  337: 'her',
#  338: 'video',
#  339: 'price',
#  340: 'work',
#  341: 'executive',
#  342: '12',
#  343: 'stock',
#  344: 'jobs',
#  345: 'near',
#  346: 'right',
#  347: 'released',
#  348: 'fourth',
#  349: 'face',
#  350: 'rose',
#  351: 'users',
#  352: 'darfur',
#  353: 'play',
#  354: 'st',
#  355: 'beat',
#  356: 'launch',
#  357: 'title',
#  358: 'europe',
#  359: 'army',
#  360: 'ago',
#  361: 'press',
#  362: 'nations',
#  363: 'apple',
#  364: 'seven',
#  365: 'aspx',
#  366: 'quickinfo',
#  367: 'man',
#  368: 'because',
#  369: 'amp',
#  370: 'bomb',
#  371: 'peoplesoft',
#  372: 'again',
#  373: 'much',
#  374: 'use',
#  375: 'uk',
#  376: 'sun',
#  377: 'study',
#  378: 'wins',
#  379: 'products',
#  380: 'nearly',
#  381: 'him',
#  382: 'digital',
#  383: 'official',
#  384: 'canadian',
#  385: 'called',
#  386: 'rise',
#  387: 'oracle',
#  388: 'drug',
#  389: 'low',
#  390: 'presidential',
#  391: '8',
#  392: '20',
#  393: 'firm',
#  394: 'reports',
#  395: 'strong',
#  396: 'pakistan',
#  397: 'israel',
#  398: '11',
#  399: 'part',
#  400: 'where',
#  401: 'race',
#  402: '9',
#  403: 'lower',
#  404: 'workers',
#  405: 'do',
#  406: 'took',
#  407: 'leaders',
#  408: 'latest',
#  409: 'korea',
#  410: 'past',
#  411: 'russia',
#  412: 'any',
#  413: 'making',
#  414: 'share',
#  415: 'charges',
#  416: 'media',
#  417: 'economy',
#  418: 'french',
#  419: 'should',
#  420: 'britain',
#  421: 'forces',
#  422: 'found',
#  423: 'being',
#  424: 'agreed',
#  425: 'school',
#  426: 'attacks',
#  427: 'bill',
#  428: 'agency',
#  429: 'your',
#  430: 'used',
#  431: 'despite',
#  432: 'japanese',
#  433: 'close',
#  434: 'west',
#  435: 'systems',
#  436: 'meeting',
#  437: 'trial',
#  438: 'chicago',
#  439: 'michael',
#  440: 'points',
#  441: 'life',
#  442: 'palestinian',
#  443: 'wall',
#  444: 'defense',
#  445: 'house',
#  446: 'best',
#  447: 'well',
#  448: 'source',
#  449: 'hurricane',
#  450: 'head',
#  451: 'e',
#  452: 'iran',
#  453: 'release',
#  454: 'around',
#  455: 'pc',
#  456: 'line',
#  457: 'financial',
#  458: 'foreign',
#  459: 'point',
#  460: 'peace',
#  461: 'winning',
#  462: '36',
#  463: 'profile',
#  464: '18',
#  465: 'per',
#  466: 'claims',
#  467: 'commission',
#  468: 'scientists',
#  469: '30',
#  470: 'america',
#  471: 'street',
#  472: 'champions',
#  473: 'fell',
#  474: 'net',
#  475: 'september',
#  476: 'tokyo',
#  477: 'hopes',
#  478: 'power',
#  479: 'kerry',
#  480: 'championship',
#  481: 'southern',
#  482: 'manager',
#  483: 'demand',
#  484: 'public',
#  485: 'due',
#  486: 'nasa',
#  487: 'support',
#  488: 'quote',
#  489: 'across',
#  490: 'killing',
#  491: 'give',
#  492: 'judge',
#  493: 'player',
#  494: 'agreement',
#  495: 'car',
#  496: 'results',
#  497: 'death',
#  498: 'server',
#  499: 'champion',
#  500: 'energy',
#  501: 'management',
#  502: 'among',
#  503: 'crude',
#  504: 'might',
#  505: 'here',
#  506: 'rally',
#  507: 'quarterly',
#  508: 'vote',
#  509: 'party',
#  510: 'shot',
#  511: 'better',
#  512: 'florida',
#  513: 'going',
#  514: 'region',
#  515: '17',
#  516: 'number',
#  517: 'times',
#  518: 'men',
#  519: 'tax',
#  520: 'little',
#  521: 'match',
#  522: 'chinese',
#  523: '24',
#  524: 'madrid',
#  525: 'costs',
#  526: 'fire',
#  527: '15',
#  528: 'offer',
#  529: 'arafat',
#  530: 'such',
#  531: 'force',
#  532: 'program',
#  533: 'department',
#  534: 'few',
#  535: 'real',
#  536: 'taking',
#  537: 'campaign',
#  538: 'afghan',
#  539: 'star',
#  540: 'stores',
#  541: 'sudan',
#  542: 'cost',
#  543: 'good',
#  544: 'cuts',
#  545: 'did',
#  546: 'led',
#  547: 'francisco',
#  548: 'launched',
#  549: 'posted',
#  550: 'leading',
#  551: 'ever',
#  552: 'increase',
#  553: 'threat',
#  554: 'airlines',
#  555: 'boost',
#  556: 'also',
#  557: 'france',
#  558: '25',
#  559: 'anti',
#  560: 'already',
#  561: 'site',
#  562: 'battle',
#  563: 'short',
#  564: 'future',
#  565: '14',
#  566: 'october',
#  567: 'california',
#  568: 'show',
#  569: 'put',
#  570: 'northern',
#  571: 'chip',
#  572: 'fall',
#  573: 'look',
#  574: 'whether',
#  575: 'morning',
#  576: 'running',
#  577: 'sony',
#  578: 'away',
#  579: 'houston',
#  580: 'both',
#  581: 'using',
#  582: 'fight',
#  583: 'sell',
#  584: 'customers',
#  585: 'hostage',
#  586: 'weeks',
#  587: 'version',
#  588: 'too',
#  589: 'east',
#  590: 'ceo',
#  591: 'warned',
#  592: '16',
#  593: 'tv',
#  594: 'following',
#  595: 'contract',
#  596: 'likely',
#  597: 'keep',
#  598: 'ready',
#  599: 'rate',
#  600: 'rival',
#  601: 'behind',
#  602: 'afghanistan',
#  603: 'australian',
#  604: 'late',
#  605: 'consumer',
#  606: 'capital',
#  607: '100',
#  608: 'gets',
#  609: 'rebel',
#  610: 'interest',
#  611: 'we',
#  612: 'putin',
#  613: 'personal',
#  614: 'place',
#  615: 'television',
#  616: 'job',
#  617: 'growing',
#  618: 'fans',
#  619: 'children',
#  620: 'conference',
#  621: 'blue',
#  622: 'takeover',
#  623: 'history',
#  624: 'mark',
#  625: 'hits',
#  626: 'rates',
#  627: 'central',
#  628: 'nine',
#  629: 'field',
#  630: 'profits',
#  631: 'return',
#  632: 'several',
#  633: 'boeing',
#  634: 'strike',
#  635: 'further',
#  636: 'see',
#  637: 'bankruptcy',
#  638: 'recent',
#  639: 'eight',
#  640: 'office',
#  641: 'charged',
#  642: 'told',
#  643: '50',
#  644: 'step',
#  645: 'reserve',
#  646: 'violence',
#  647: 'fighting',
#  648: '13',
#  649: 'baseball',
#  650: 'singapore',
#  651: 'sale',
#  652: 'medal',
#  653: 'amid',
#  654: 'small',
#  655: 'nation',
#  656: 'chairman',
#  657: 'less',
#  658: 'calls',
#  659: 'communications',
#  660: 'become',
#  661: 'oct',
#  662: 'supply',
#  663: 'decision',
#  664: 'operating',
#  665: 'come',
#  666: 'level',
#  667: 'yahoo',
#  668: 'canada',
#  669: 'file',
#  670: 'august',
#  671: 'human',
#  672: 'tour',
#  673: 'corporate',
#  674: 'own',
#  675: 'rules',
#  676: 'miss',
#  677: 'board',
#  678: 'change',
#  679: 'tech',
#  680: 'insurance',
#  681: 'kill',
#  682: 'teams',
#  683: 'desktop',
#  684: 'phones',
#  685: 'soldiers',
#  686: 'november',
#  687: 'club',
#  688: 'almost',
#  689: 'radio',
#  690: 'western',
#  691: 'showed',
#  692: 'got',
#  693: 'ban',
#  694: 'helped',
#  695: 'women',
#  696: 'members',
#  697: 'gas',
#  698: "world's",
#  699: 'within',
#  700: 'probe',
#  701: 'career',
#  702: 'dead',
#  703: 'elections',
#  704: 'scored',
#  705: 'engine',
#  706: 'ivan',
#  707: 'militants',
#  708: 'secretary',
#  709: 'station',
#  710: 'information',
#  711: 'manchester',
#  712: 'signed',
#  713: 'political',
#  714: 'computers',
#  715: 'mail',
#  716: 'money',
#  717: 'far',
#  718: 'she',
#  719: 'possible',
#  720: 'm',
#  721: 'health',
#  722: '27',
#  723: '21',
#  724: 'takes',
#  725: 'council',
#  726: 'aol',
#  727: 'david',
#  728: 'chips',
#  729: 'paul',
#  730: 'airways',
#  731: 'earlier',
#  732: 'cricket',
#  733: 'indian',
#  734: 'networks',
#  735: 'forecast',
#  736: 'drop',
#  737: 'yet',
#  738: 'weekend',
#  739: 'ended',
#  740: 'olympics',
#  741: 'white',
#  742: 'hold',
#  743: 'weapons',
#  744: 'cisco',
#  745: 'full',
#  746: 'makes',
#  747: 'food',
#  748: 'euro',
#  749: 'control',
#  750: 'devices',
#  751: 'aid',
#  752: 'same',
#  753: 'arsenal',
#  754: 'ipod',
#  755: 'rivals',
#  756: '500',
#  757: 'spain',
#  758: 'coast',
#  759: 'spam',
#  760: 'designed',
#  761: 'those',
#  762: 'stadium',
#  763: 'pm',
#  764: 'sign',
#  765: 'accused',
#  766: 'exchange',
#  767: 'labor',
#  768: 'post',
#  769: 'barrel',
#  770: 'local',
#  771: 'administration',
#  772: 'paris',
#  773: 'los',
#  774: 'basketball',
#  775: 'kills',
#  776: 'speed',
#  777: 'stake',
#  778: 'without',
#  779: 'cash',
#  780: 'rebels',
#  781: 'then',
#  782: 'signs',
#  783: 'product',
#  784: 'others',
#  785: 'injured',
#  786: 'opening',
#  787: 'senate',
#  788: 'atlanta',
#  789: 'evidence',
#  790: 'african',
#  791: 'issue',
#  792: 'nov',
#  793: 'drive',
#  794: 'ltd',
#  795: 'injury',
#  796: 'nfl',
#  797: 'crisis',
#  798: 'law',
#  799: 'wants',
#  800: 'revenue',
#  801: 'shows',
#  802: 'thousands',
#  803: 'family',
#  804: 'satellite',
#  805: 'coming',
#  806: 'unit',
#  807: 'find',
#  808: 'heart',
#  809: 'hours',
#  810: 'side',
#  811: 'experts',
#  812: 'concerns',
#  813: 'cbs',
#  814: 'markets',
#  815: 'fund',
#  816: 'performance',
#  817: 'investment',
#  818: 'prize',
#  819: 'risk',
#  820: 'sees',
#  821: 'hard',
#  822: 'retailer',
#  823: 'seen',
#  824: 'charge',
#  825: 'failed',
#  826: 'aimed',
#  827: 'beijing',
#  828: 'toward',
#  829: 'angeles',
#  830: 'merger',
#  831: 'great',
#  832: 'yukos',
#  833: 'authorities',
#  834: 'turkey',
#  835: 'terror',
#  836: 'looking',
#  837: 'legal',
#  838: '23',
#  839: 'hundreds',
#  840: 'grand',
#  841: 'died',
#  842: 'airline',
#  843: 'very',
#  844: 'williams',
#  845: 'germany',
#  846: 'german',
#  847: 'countries',
#  848: 'ruling',
#  849: 'action',
#  850: 'stop',
#  851: 're',
#  852: 'once',
#  853: 'explosion',
#  854: 'bowl',
#  855: 'ruled',
#  856: 'c',
#  857: 'giants',
#  858: 'soccer',
#  859: 'taiwan',
#  860: 'texas',
#  861: 'fraud',
#  862: 'rights',
#  863: 'filed',
#  864: 'came',
#  865: 'holding',
#  866: 'getting',
#  867: 'private',
#  868: 'association',
#  869: 'arrested',
#  870: 'focus',
#  871: 'gains',
#  872: 'offensive',
#  873: 'reached',
#  874: 'call',
#  875: 'warning',
#  876: 'park',
#  877: 'groups',
#  878: 'saying',
#  879: 'seeks',
#  880: 'continue',
#  881: 'each',
#  882: 'cell',
#  883: 'operations',
#  884: 'size',
#  885: 'outside',
#  886: 'dell',
#  887: 'production',
#  888: 'yankees',
#  889: 'potential',
#  890: 'soon',
#  891: 'sent',
#  892: 'begin',
#  893: 'fired',
#  894: 'center',
#  895: 'sept',
#  896: 'miami',
#  897: 'strip',
#  898: 'analysts',
#  899: 'blast',
#  900: 'outlook',
#  901: 'astros',
#  902: 'electronics',
#  903: 'main',
#  904: '151',
#  905: 'double',
#  906: 'flight',
#  907: 'visit',
#  908: 'named',
#  909: 'gives',
#  910: 'amazon',
#  911: 'competition',
#  912: 'changes',
#  913: 'settle',
#  914: 'code',
#  915: 'problems',
#  916: 'italian',
#  917: 'reach',
#  918: 'cardinals',
#  919: 'pressure',
#  920: 'card',
#  921: 'given',
#  922: 'supreme',
#  923: 'turn',
#  924: 'palestinians',
#  925: 'gave',
#  926: 'sources',
#  927: '2006',
#  928: 'working',
#  929: 'raised',
#  930: 'efforts',
#  931: 'trading',
#  932: 'trying',
#  933: "it's",
#  934: 'font',
#  935: 'sanctions',
#  936: 'fuel',
#  937: 'access',
#  938: 'americans',
#  939: 'try',
#  940: 'finally',
#  941: 'until',
#  942: 'consumers',
#  943: 'black',
#  944: 'popular',
#  945: 'runs',
#  946: 'executives',
#  947: 'policy',
#  948: 'louis',
#  949: 'staff',
#  950: 'launches',
#  951: 'lost',
#  952: 'regulators',
#  953: 'tests',
#  954: 'hp',
#  955: 'officer',
#  956: 'taken',
#  957: 'division',
#  958: 'democratic',
#  959: 'never',
#  960: 'green',
#  961: 'jump',
#  962: 'browser',
#  963: 'enterprise',
#  964: 'researchers',
#  965: 'sharon',
#  966: 'toronto',
#  967: 'generation',
#  968: 'yards',
#  969: 'spanish',
#  970: 'order',
#  971: 'woods',
#  972: 'asked',
#  973: 'fed',
#  974: 'want',
#  975: 'nokia',
#  976: 'africa',
#  977: 'bay',
#  978: 'michigan',
#  979: 'annual',
#  980: 'single',
#  981: 'aircraft',
#  982: 'jones',
#  983: 'list',
#  984: 'december',
#  985: 'flat',
#  986: 'known',
#  987: 'warner',
#  988: 'firms',
#  989: 'proposal',
#  990: 'university',
#  991: 'buying',
#  992: 'airport',
#  993: 'term',
#  994: 'large',
#  995: 'suit',
#  996: 'seeking',
#  997: 'cent',
#  998: 'worth',
#  999: 'does',
#  1000: 'dollars',
#  ...}

# %%
sample_review = X_train[0]
sample_label = y_train[0]

print(f"Sample review (as integers): {sample_review}")
print(f'Sample label: {sample_label}')
# Out:
# Sample review (as integers): [122, 479, 217, 1, 594, 1193, 1, 2984, 78, 122, 8, 69, 4355, 60, 1736]
# Sample label: 0

# %%
decoded_review = ' '.join([reverse_word_index.get(i, '?') for i in sample_review])
decoded_review
# Out:
# 'bush kerry trade <OOV> following debate <OOV> pa president bush on friday ripped into sen'

# %%
from tensorflow.keras.preprocessing import sequence

max_len = 100

X_train = sequence.pad_sequences(X_train, maxlen=max_len)
X_test = sequence.pad_sequences(X_test, maxlen=max_len)
X_train
# Out:
# array([[   0,    0,    0, ..., 4355,   60, 1736],
#        [   0,    0,    0, ...,  196,  156, 1663],
#        [   0,    0,    0, ...,    5, 1834,  319],
#        ...,
#        [   0,    0,    0, ...,   33, 4535,   32],
#        [   0,    0,    0, ...,    5,    1, 2470],
#        [   0,    0,    0, ..., 1313, 8062,   12]])

# %%
## Train LSTM Model
model = Sequential()
model.add(Embedding(max_features, 128, input_length=max_len))  # Embedding Layer
model.add(LSTM(128, activation='relu'))
model.add(Dense(4, activation="softmax"))  # 4 classes: World, Sports, Business, Sci/Tech
# Out:
# WARNING:tensorflow:From E:\anaconda3\envs\senti\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 100, 128)          1280000
#
#  lstm (LSTM)                 (None, 128)               131584
#
#  dense (Dense)               (None, 4)                 516
#
# =================================================================
# Total params: 1412100 (5.39 MB)
# Trainable params: 1412100 (5.39 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From E:\anaconda3\envs\senti\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
## Create an instance of EarlyStopping Callback
from tensorflow.keras.callbacks import EarlyStopping
earlystopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
earlystopping

# %%
history = model.fit(
    X_train, y_train, epochs=10, batch_size=32,
    validation_split=0.2,
    callbacks=[earlystopping]
)
# Out:
# Epoch 1/10
# WARNING:tensorflow:From E:\anaconda3\envs\senti\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From E:\anaconda3\envs\senti\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 152/152 [==============================] - 23s 141ms/step - loss: 3.9087 - accuracy: 0.4924 - val_loss: 1.2875 - val_accuracy: 0.6291
# Epoch 2/10
# 152/152 [==============================] - 21s 138ms/step - loss: 1.6716 - accuracy: 0.6793 - val_loss: 1.2642 - val_accuracy: 0.6365
# Epoch 3/10
# 152/152 [==============================] - 24s 157ms/step - loss: 1.1785 - accuracy: 0.7743 - val_loss: 1.1597 - val_accuracy: 0.6867
# Epoch 4/10
# 152/152 [==============================] - 24s 156ms/step - loss: 1716.4038 - accuracy: 0.7858 - val_loss: 1.1815 - val_accuracy: 0.5872
# Epoch 5/10
# 152/152 [==============================] - 22s 147ms/step - loss: 1.0583 - accuracy: 0.7251 - val_loss: 1.1041 - val_accuracy: 0.6521
# Epoch 6/10
# 152/152 [==============================] - 22s 146ms/step - loss: 0.9392 - accuracy: 0.8053 - val_loss: 1.0250 - val_accuracy: 0.6711
# Epoch 7/10
# 152/152 [==============================] - 23s 153ms/step - loss: 0.8063 - accuracy: 0.8425 - val_loss: 0.9872 - val_accuracy: 0.6891
# Epoch 8/10
# 152/152 [==============================] - 22s 143ms/step - loss: 0.6830 - accuracy: 0.8682 - val_loss: 0.8661 - val_accuracy: 0.7007
# Epoch 9/10
# 152/152 [==============================] - 23s 149ms/step - loss: 0.5859 - accuracy: 0.8840 - val_loss: 0.9353 - val_accuracy: 0.6702
# Epoch 10/10
# 152/152 [==============================] - 22s 146ms/step - loss: 0.6098 - accuracy: 0.8672 - val_loss: 0.8741 - val_accuracy: 0.6982

# %%
model.save('lstm_news_classification.h5')
# Out:
# E:\anaconda3\envs\senti\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Save the tokenizer for later use
import pickle
with open('news_tokenizer_lstm.pkl', 'wb') as f:
    pickle.dump(tokenizer, f)

# %%
# Evaluate the model on test data
test_loss, test_accuracy = model.evaluate(X_test, y_test)

print(f'Test Loss: {test_loss}')
print(f'Test Accuracy: {test_accuracy}')
# Out:
# 48/48 [==============================] - 2s 41ms/step - loss: 0.9053 - accuracy: 0.6921
# Test Loss: 0.9053300023078918
# Test Accuracy: 0.692105233669281
